# %% [markdown]
# ***
# ***
#
# <strong><h1>Text-Adventure-Game-Development</h1></strong>
#
#
# <strong><br>This game should utilize the Python essentials including, but not limited to:</strong><br>
#
#
#
# 1) Strings and String Manipulation
#
# 2) User-Defined Functions and Variables
#
# 3) User Input and Input Handling
#
# 4) Conditional and Nested Conditional Statements (if/elif/else)
#
# 6) Loops Controlling for Errors

# %%
print('      ___           ___                       ___                       ___       ')
print('     /__/\         /  /\          ___        /  /\        ___          /__/|      ')
print('    |  |::\       /  /::\        /  /\      /  /::\      /  /\        |  |:|      ')
print('    |  |:|:\     /  /:/\:\      /  /:/     /  /:/\:\    /  /:/        |  |:|      ')
print('  __|__|:|\:\   /  /:/~/::\    /  /:/     /  /:/~/:/   /__/::\      __|__|:|      ')
print(' /__/::::| \:\ /__/:/ /:/\:\  /  /::\    /__/:/ /:/___ \__\/\:\__  /__/::::\____  ')
print(' \  \:\~~\__\/ \  \:\/:/__\/ /__/:/\:\   \  \:\/:::::/    \  \:\/\    ~\~~\::::/  ')
print('  \  \:\        \  \::/      \__\/  \:\   \  \::/~~~~      \__\::/     |~~|:|~~   ')
print('   \  \:\        \  \:\           \  \:\   \  \:\          /__/:/      |  |:|     ')
print('    \  \:\        \  \:\           \__\/    \  \:\         \__\/       |  |:|     ')
print('     \__\/         \__\/                     \__\/                     |__|/      '+ '\n\n')

print(chr(27)+"[7;32m"+"***WELCOME TO THE MATRIX*** \n\nYou are going to have an amazing time playing this game")

import webbrowser
  
while True:

  ready=input(prompt="Are you ready? \nplease write yes or no ")
  if ready == 'yes'or ready =='YES' or ready=='Yes':
     print(chr(27)+ "[7;37m" + '\n\nGreat, Let´s start!!')
     break
  elif ready== 'no' or ready =='NO' or ready=='No':
     print(chr(27)+ "[7;37m" + '\nI am sorry to read that, You could be the next Neo')
     continue 
    
print("To start the game, you should input your name or the system will choose one for you")

while True:
   
  name=input(prompt="a. Input my name \nb. I want the system to choose it for me")
  if name.lower()!='a' and name.lower()!='b' :
        print('\nPlease write only a or b')
        continue 
  elif name.lower() == 'a' or name.lower()=='b':
        if name.lower()=='a':
            name=input('write your name')
            while True:
                if name!='':
                    break
                else:
                    name=input('write your name')
                    continue    
        elif name.lower()=='b':
            name='Akira'
            print(chr(27)+ "[7;32m" + '\n\nYour name now is Akira')
        break

  
  
print(chr(27)+ "[7;32m" + f'\nHello {name}')
 
print("""\nIn the last fight against the agents, Neo died \nYes I know, it\'s a shame \nThat is why Morpheus is looking for a new hero, and apparently you are the best candidate \nHow incredible is that!!""")
print("\n****This game has 5 levels and, to win the game you have to get to the final battle and beat the Agents \n(the bad guys of the Matrix)**** \n\nEverytime you make a mistake, you will lose Morpheus Trust. \nThat is why you can only make 3 mistakes otherwise you will lose the game!!!")
input('<Press enter to continue>\n')


# LEVEL 1

print(chr(27)+ "[7;37m" + '\n\nTo make the game more exciting, when you press enter, a video on YouTube will be automatically opened \nwith the soundtrack of the Matrix movie, to continue with the game you must return to the page where the game is running.')
input('<Press enter to continue>\n')
webbrowser.open("https://www.youtube.com/watch?v=dzLhi63Vyjw&t=998s", new=2, autoraise=True)

print(chr(27)+"[7;34m"+f'%'*96+'\nLEVEL 1 \n\nTo prove that you are the right candidate, you should go to a club called Trinity, and follow a girl with a special tatoo.')

while True:
  rabbit=input(prompt='\nNow you must decide which girl are you going to follow: \na. Girl with a white rabbit tatoo \nb. Girl with a red lion tatoo \nc. Girl with a green dragon tatoo \nWrite just one letter: a, b or c in lower case')

  if rabbit.lower() == 'a':
          print(chr(27)+ "[7;37m" + '\n\nNice job, You made the right decision!!')
          break
    
  elif rabbit.lower()== 'b' or rabbit.lower()=='c':
          print(chr(27)+ "[7;37m" + '\n\nWrong choice, you don´t score points')
          break

score=0
failed_attempts=0

if rabbit.lower()=='a':
    score = score + 100
    failed_attempts=failed_attempts+0
elif rabbit.lower() != 'a':
    score = score + 0
    failed_attempts=failed_attempts+1
else:    
    score = score + 0
    failed_attempts=failed_attempts+1

print('\n\nYour score is ' + str(score))

if rabbit.lower() != 'a': 
    print('The number of your mistakes is: ' + str(failed_attempts) + '\nBe more carefull in the following challenges')

# LEVEL 2

input('<Press enter to continue>\n')

print(chr(27)+"[7;35m"+f'%'*96+'\nLEVEL 2 \n\nMorpheus will ask you a very importan question \nThink very carefully about the answer..')

while True:
  pill=input(prompt='\nWhich pill do you want to take? \na. Blue pill: life of security, luxury, and the blissful ignorance \nb. Red pill: Real freedom and the brutal truths of reality \nWrite just one letter: a or b in lower case')

  if pill.lower() == 'b':
       print(chr(27)+ "[7;37m" + '\n\nWise decision, You will be disconected of the Matrix to discover the real world!!')
       break 
  elif pill.lower() == 'a':
       print(chr(27)+ "[7;37m" + '\n\nWrong choice, you don´t score points')
       break
       
        
if pill.lower()=='b':
    score = score + 100
    failed_attempts=failed_attempts+0
elif pill.lower() != 'b':
    score = score + 0
    failed_attempts=failed_attempts+1
else:    
    score = score + 0
    failed_attempts=failed_attempts+1

print('Your score now is ' + str(score))

if pill.lower() != 'b': 
    print('The number of your mistakes is: ' + str(failed_attempts) + '\nBe more carefull in the following challenges')

# LEVEL 3

import sys as sys
def fail():
    print(chr(27)+"[7;30m"+"You've failed, but thanks for playing! \n\n")
    print(chr(27)+"[7;30m"+"""  /$$$$$$   /$$$$$$  /$$      /$$ /$$$$$$$$        /$$$$$$  /$$    /$$ /$$$$$$$$ /$$$$$$$       
 /$$__  $$ /$$__  $$| $$$    /$$$| $$_____/       /$$__  $$| $$   | $$| $$_____/| $$__  $$      
| $$  \__/| $$  \ $$| $$$$  /$$$$| $$            | $$  \ $$| $$   | $$| $$      | $$  \ $$      
| $$ /$$$$| $$$$$$$$| $$ $$/$$ $$| $$$$$         | $$  | $$|  $$ / $$/| $$$$$   | $$$$$$$/      
| $$|_  $$| $$__  $$| $$  $$$| $$| $$__/         | $$  | $$ \  $$ $$/ | $$__/   | $$__  $$      
| $$  \ $$| $$  | $$| $$\  $ | $$| $$            | $$  | $$  \  $$$/  | $$      | $$  \ $$      
|  $$$$$$/| $$  | $$| $$ \/  | $$| $$$$$$$$      |  $$$$$$/   \  $/   | $$$$$$$$| $$  | $$      
 \______/ |__/  |__/|__/     |__/|________/       \______/     \_/    |________/|__/  |__/""")
      
    input('<Press enter to exit>\n')
    sys.exit() 

input('<Press enter to continue>\n')

print(chr(27)+"[7;31m"+f'%'*96+'\nLEVEL 3 \n\nYou have been disconected from the Matrix, and now you know the truth about the world \nEveryone´s life is an illusion.  \nIn order to save all mankind, you need to know how to fight')

while True:

  training=input(prompt='\nWhich martial art would you like to learn? \na. Kung Fu \nb. Taekwondo \nc. Karate \nWrite just one letter: a, b or c in lower case')
  if training.lower() == 'a' or training.lower()  == 'b' or training.lower()  == 'c' :
     print(chr(27)+ "[7;37m" + '\n\nNice choice, you will become an expert in that martial art!!')
     break
  elif training.lower()  != 'a' or training.lower()  != 'b' or training.lower()  != 'c':
     print(chr(27)+ "[7;37m" + '\nWrite just one letter: a, b or c in lower case')
     continue 

input('<Press enter to continue>\n')

martial_art='' 

if training.lower() =='a':
    martial_art='Kung Fu'        
elif training.lower() =='b':
    martial_art='Taekwondo'                    
elif training.lower() =='c':
    martial_art='Karate'                    
else: 'how to fight' 

print(chr(27)+ "[7;37m" + f'\nNow that you became an expert in {martial_art}, you must fight vs Morpheus to show what you learned')
        

while True:
  fight=input(prompt='\nWhich technique will you use? \na. Kick in the face \nb. Punch in the stomach \nc. Run and hide \nWrite just one letter: a,b or b in lower case')
  if fight.lower()== 'a'or fight.lower() == 'b' :
       print(chr(27)+ "[7;32m" + '\n\nGreat movement, Morpheus is impressed with your performance, you go to the next level !!')
       break   
  elif fight.lower()== 'c':
       print(chr(27)+ "[7;32m" + '\n\nWrong choice, you don´t score points')
       break
        
if fight.lower() == 'a'or fight.lower() == 'b' :
    score = score + 100
    failed_attempts=failed_attempts+0
elif fight.lower() != 'c':
    score = score + 0
    failed_attempts=failed_attempts+1
else:    
    score = score + 0
    failed_attempts=failed_attempts+1

print('Your score now is ' + str(score))

if fight.lower() != 'a' and fight.lower() != 'b': 
    print('\nThe number of your mistakes is: ' + str(failed_attempts)) 
    if failed_attempts<3 :
        print('\nBe more carefull in the following challenges')
    else: 
        fail()
     
        
# LEVEL 4

input('<Press enter to continue>\n')

print(chr(27)+"[7;36m"+f'%'*96+'\nLEVEL 4 \n\nMorpheus have been captured by the agent Smith, the cruelest villian of the Matrix, and you have to rescue him \nFor this mission, you need to choose a weapon')

while True:

  weapon=input(prompt='\nChoose a weapon \na. Machine gun \nb. Samurai Sword \nc. Bazooka \nWrite just one letter: a, b or c in lower case')

  if weapon.lower() == 'a' or weapon.lower() == 'b' or weapon.lower() == 'c' :
     print(chr(27)+ "[7;37m" + '\n\nThat´s a really powerful weapon, nice choice!!')
     break
  elif weapon.lower() != 'a' or weapon.lower() != 'b' or weapon.lower() != 'c':
     print(chr(27)+ "[7;37m" + '\nPlease, write just one letter: a, b or c in lower case')
     continue 

####

rescuing_Morpheus='' 

if weapon.lower()=='a':
    rescuing_Morpheus='You killed all the agents that captured Morpheus using your powerful machine gun'        
elif weapon.lower()=='b':
    rescuing_Morpheus='You showed all your skill using the Samurai sword and defeated all the agents'                    
elif weapon.lower()=='c':
    rescuing_Morpheus='Using the bazooka, you destroy half of the building where Morpheus was captured, fortunately Morpheus is still alive'                    
else: print('There is a problem in the system')

input('<Press enter to continue>\n')
    
print(chr(27)+ "[7;36m" + f'\n{rescuing_Morpheus} \nAfter killing all the bad guys, you used a helicopter to be closer to Morpheus \nso he could jump in to the helicopter \nMorpheus looks tired so you are not sure if he could make it \nNow you have to make a life or death decision:')
 
while True:
    
  jump=input(prompt='\n\na. You will jump at the same time to catch him \nb. You trust in his strength so you will wait for him in the helicopter  \nc. You will leave Morpheus because the agents could come back \nWrite just one letter: a,b or b in lower case')

  if jump.lower() == 'a':
       print(chr(27)+ "[7;37m" + '\n\nPerfect decision, you saved Morpheus cause otherwise he could not make it, you go to the next level !!')
       break
  elif jump.lower() == 'b':
       print(chr(27)+ "[7;37m" + '\n\nMorpheus could not complete the jump, he is lying in the floor now. That was a wrong decision')
       break 
  elif jump.lower()== 'c':
       print(chr(27)+ "[7;37m" + '\n\nWhat kind of hero are you??')
       break 
  else:
       print('There is a problem in the system')
       

if jump.lower() == 'a':
    score = score + 100
    failed_attempts=failed_attempts+0
elif jump.lower() == 'b':
    score = score + 0
    failed_attempts=failed_attempts+1 
else:    
    score = score + 0
    failed_attempts=failed_attempts+1

print('Your score now is ' + str(score))

if jump.lower() != 'a' : 
    print('\nThe number of your mistakes is: ' + str(failed_attempts)) 
    if failed_attempts<3 :
        print('\nBe more carefull in the FINAL CHALLENGE')
    elif failed_attempts>=3 :
        fail()
    else: fail() 

# LEVEL 5- FINAL BATTLE

def win():
    print(chr(27)+"[7;30m"+'Your final score is ' + str(score + 100))
    print(chr(27)+"[7;30m"+'\n\n   ')
    print(chr(27)+"[7;30m"+'101    101  101010101   101   101     101           101  101010101  0101     101    ')
    print(chr(27)+"[7;30m"+' 010  010   010   010   010   010      010         010   010   010  10101    010    ')
    print(chr(27)+"[7;30m"+'  101010    101   101   101   101      101         101   101   101  010 10   101    ')
    print(chr(27)+"[7;30m"+'   010      010   010   010   010       010  101  010    010   010  101  01  010    ')
    print(chr(27)+"[7;30m"+'   101      101   101   101   101       101 01 10 101    101   101  010  10  101    ')
    print(chr(27)+"[7;30m"+'   010      010   010   010   010        0101   1010     010   010  101   01 010    ')
    print(chr(27)+"[7;30m"+'   101      101010101   101010101        101     101     101010101  010   010101    ')
    input(chr(27)+"[7;30m"+'<Press any key to exit>\n')    
  
    
input('<Press enter to continue>\n')

import random

bullets=random.randint(3,21)
stop_bullets=12

print(chr(27)+"[7;30m"+f'%'*96+'\n******LEVEL 5- FINAL BATTLE****** \n\nAfter all the effort you put in the last challenge, \nyou could save Morpheus and now you have to return to the ship')
print('\n\nBut just while you were receiving the call to be taken out of the Matrix, \na bullet destroy your phone. \nYou have no option but to fight against the agents')
print(f"""\nYou are in front of 3 agents and they start shooting \nDuring your training you learned how to stop a maximum of {stop_bullets} bullets""")
print('\nIf you stop the bullets, all the agents will escape because they are cowards but if you cannot stop all the bullets, you will be hurt and they will kill you \nThe agent´s guns have a maximum of 7 bullets [Hint: A maximum of 21 bullets in total]')   

while True:

  final_decision=input(prompt='\nThe following decision will decide if you win or lose the game:  \na. I will escape to stay alive and fight another day \nb. I will stop the bullets and show them who is the boss \nc. I will try to fix the phone and go back to the ship  \nWrite just one letter: a, b or c in lower case')
  if final_decision.lower()=='a' or final_decision.lower()== 'b' :
     print(chr(27)+ "[7;37m" + f'\n\n{bullets} bullets were fired!!!!')
     break
  if final_decision.lower()=='c':
     print(chr(27)+ "[7;37m" + '\nAre you crazy??? you are death now! ')
     fail()
  elif final_decision.lower() != 'a' or final_decision.lower() != 'b' or final_decision.lower() != 'c':
     print(chr(27)+ "[7;37m" + '\nPlease, write just one letter: a, b or c in lower case')


input('\n\n<Press enter to continue>\n')
print(chr(27)+"[7;36m"+'\n\n'+f'%'*96)

destiny='' 

if bullets >stop_bullets and final_decision.lower()== 'a' :
    destiny='You are a wise man, it is better to live and fight another day'
    print(destiny)
    win()
elif bullets >stop_bullets and final_decision.lower()== 'b' :
    destiny='You are brave but unfortunately the bullets fired were more than 12. YOU ARE DEAD' 
    print(destiny)
    fail()
elif bullets <=stop_bullets and final_decision.lower()== 'a' :
    destiny='You are a coward, you don´t deserve to be the next Neo' 
    print(destiny)
    fail()
elif bullets <=stop_bullets and final_decision.lower()== 'b' :
    destiny='YOU STOP ALL THE BULLETS \nYOU ARE TRULY THE CHOSEN ONE!!!'
    print(destiny)
    win()
else: print('There is a problem in the system')
# Out:
#       ___           ___                       ___                       ___
#      /__/\         /  /\          ___        /  /\        ___          /__/|
#     |  |::\       /  /::\        /  /\      /  /::\      /  /\        |  |:|
#     |  |:|:\     /  /:/\:\      /  /:/     /  /:/\:\    /  /:/        |  |:|
#   __|__|:|\:\   /  /:/~/::\    /  /:/     /  /:/~/:/   /__/::\      __|__|:|
#  /__/::::| \:\ /__/:/ /:/\:\  /  /::\    /__/:/ /:/___ \__\/\:\__  /__/::::\____
#  \  \:\~~\__\/ \  \:\/:/__\/ /__/:/\:\   \  \:\/:::::/    \  \:\/\    ~\~~\::::/
#   \  \:\        \  \::/      \__\/  \:\   \  \::/~~~~      \__\::/     |~~|:|~~
#    \  \:\        \  \:\           \  \:\   \  \:\          /__/:/      |  |:|
#     \  \:\        \  \:\           \__\/    \  \:\         \__\/       |  |:|
#      \__\/         \__\/                     \__\/                     |__|/
#
#
# ***WELCOME TO THE MATRIX***
#
# You are going to have an amazing time playing this game
# Are you ready?
# ...
